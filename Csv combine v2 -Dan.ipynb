# %%
import os
import pandas as pd
import csv

# %%
#import data
q1= "Id/2017 q1.csv"
q2= "Id/2017 q2.csv"
q3= "Id/2017 q3.csv"
q4= "Id/2017 q4.csv"
q5= "Id/2018 q1.csv"
q6= "Id/2018 q2.csv"
q7= "Id/2018 q3.csv"
q8= "Id/2018 q4.csv"
q9= "Id/2019 q1.csv"
q10= "Id/2019 q2.csv"
q11= "Id/2019 q3.csv"
q12= "Id/2019 q4.csv"

# %%
#set them all as df
q1= pd.read_csv(q1)
q2= pd.read_csv(q2)
q3= pd.read_csv(q3)
q4= pd.read_csv(q4)
q5= pd.read_csv(q5)
q6= pd.read_csv(q6)
q7= pd.read_csv(q7)
q8= pd.read_csv(q8)
q9= pd.read_csv(q9)
q10= pd.read_csv(q10)
q11= pd.read_csv(q11)
q12= pd.read_csv(q12)

# %%
#test 1
q1.head(10)
# Out:
#   area_fips  own_code  industry_code  agglvl_code  size_code  year  qtr  \
# 0      1000         0             10           50          0  2017    1
# 1      1000         1             10           51          0  2017    1
# 2      1000         2             10           51          0  2017    1
# 3      1000         3             10           51          0  2017    1
# 4      1000         5             10           51          0  2017    1
# 5      1000         8             10           96          0  2017    1
# 6      1001         0             10           70          0  2017    1
# 7      1001         1             10           71          0  2017    1
# 8      1001         2             10           71          0  2017    1
# 9      1001         3             10           71          0  2017    1
#
#   disclosure_code  qtrly_estabs  month1_emplvl  ...  oty_month3_emplvl_chg  \
# 0             NaN        122888        1902835  ...                  25666
# ...

# %%
#test 2
q1.columns
# Out:
# Index(['area_fips', 'own_code', 'industry_code', 'agglvl_code', 'size_code',
#        'year', 'qtr', 'disclosure_code', 'qtrly_estabs', 'month1_emplvl',
#        'month2_emplvl', 'month3_emplvl', 'total_qtrly_wages',
#        'taxable_qtrly_wages', 'qtrly_contributions', 'avg_wkly_wage',
#        'lq_disclosure_code', 'lq_qtrly_estabs', 'lq_month1_emplvl',
#        'lq_month2_emplvl', 'lq_month3_emplvl', 'lq_total_qtrly_wages',
#        'lq_taxable_qtrly_wages', 'lq_qtrly_contributions', 'lq_avg_wkly_wage',
#        'oty_disclosure_code', 'oty_qtrly_estabs_chg',
#        'oty_qtrly_estabs_pct_chg', 'oty_month1_emplvl_chg',
#        'oty_month1_emplvl_pct_chg', 'oty_month2_emplvl_chg',
#        'oty_month2_emplvl_pct_chg', 'oty_month3_emplvl_chg',
#        'oty_month3_emplvl_pct_chg', 'oty_total_qtrly_wages_chg',
#        'oty_total_qtrly_wages_pct_chg', 'oty_taxable_qtrly_wages_chg',
#        'oty_taxable_qtrly_wages_pct_chg', 'oty_qtrly_contributions_chg',
# ...

# %%
# make a list of df, iterate through them dropping the chaff
dataframes=[q1,q2,q3,q4,q5,q6,q7,q8,q9,q10,q11,q12]
for df in dataframes:
    df.drop(columns=['own_code', 'industry_code', 'agglvl_code', 'size_code','disclosure_code','qtrly_contributions',
                    'lq_disclosure_code','lq_qtrly_contributions','oty_disclosure_code'], inplace=True)

# %%
# ensure that null columns are dropped
q1.head(10)
# Out:
#   area_fips  year  qtr  qtrly_estabs  month1_emplvl  month2_emplvl  \
# 0      1000  2017    1        122888        1902835        1916520
# 1      1000  2017    1          1211          53361          53326
# 2      1000  2017    1          1391          94177          95743
# 3      1000  2017    1          3709         212066         212732
# 4      1000  2017    1        116577        1543231        1554719
# 5      1000  2017    1          6311         359604         361801
# 6      1001  2017    1           861          10672          10720
# 7      1001  2017    1            12             87             82
# 8      1001  2017    1            19            592            589
# 9      1001  2017    1            32           1906           1901
#
#    month3_emplvl  total_qtrly_wages  taxable_qtrly_wages  avg_wkly_wage  ...  \
# 0        1928087        22243408796           9320258926            893  ...
# ...

# %%
#combine into one dataframe
combined_df = pd.concat(dataframes, axis=0, ignore_index=True)
combined_df
# Out:
#        area_fips  year  qtr  qtrly_estabs  month1_emplvl  month2_emplvl  \
# 0           1000  2017    1        122888        1902835        1916520
# 1           1000  2017    1          1211          53361          53326
# 2           1000  2017    1          1391          94177          95743
# 3           1000  2017    1          3709         212066         212732
# 4           1000  2017    1        116577        1543231        1554719
# ...          ...   ...  ...           ...            ...            ...
# 230863     US000  2019    4        302338       22206240       22316982
# 230864     US000  2019    4      10302653      146690756      147415971
# 230865     USCMS  2019    4       7460628      114753888      115428587
# 230866     USMSA  2019    4       8391197      129578942      130349516
# 230867     USNMS  2019    4       1972621       19948732       19910805
#
#         month3_emplvl  total_qtrly_wages  taxable_qtrly_wages  avg_wkly_wage  \
# ...

# %%
combined_df.to_csv('2017-2019', index=False)
