# %%
import os
import pandas as pd
import csv

# %%
#import data
q1_path = "Id/2014 q1.csv"
q2_path = "Id/2014 q2.csv"
q3_path = "Id/2014 q3.csv"
q4_path = "Id/2014 q4.csv"
q5_path = "Id/2015 q1.csv"
q6_path =  "Id/2015 q2.csv"
q7_path = "Id/2015 q3.csv"
q8_path = "Id/2015 q4.csv"
q9_path = "Id/2016 q1.csv"
q10_path = "Id/2016 q2.csv"
q11_path = "Id/2016 q3.csv"
q12_path = "Id/2016 q4.csv"

# %%
#set them all as df
q1 = pd.read_csv(q1_path)
q2 = pd.read_csv(q2_path)
q3 = pd.read_csv(q3_path)
q4 = pd.read_csv(q4_path)
q5 = pd.read_csv(q5_path)
q6 = pd.read_csv(q6_path)
q7 = pd.read_csv(q7_path)
q8 = pd.read_csv(q8_path)
q9 = pd.read_csv(q9_path)
q10 = pd.read_csv(q10_path)
q11 = pd.read_csv(q11_path)
q12 = pd.read_csv(q12_path)
q13 = pd.read_csv(q13_path)
q14 = pd.read_csv(q14_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #set them all as df
# ----> 2 q1 = pd.read_csv(q1)
#       3 q2 = pd.read_csv(q2)
#       4 q3 = pd.read_csv(q3)
#
# NameError: name 'q1' is not defined

# %%
#test 1
q1.head(10)
# Out:
#   area_fips  own_code  industry_code  agglvl_code  size_code  year  qtr  \
# 0      1000         0             10           50          0  2020    1
# 1      1000         1             10           51          0  2020    1
# 2      1000         2             10           51          0  2020    1
# 3      1000         3             10           51          0  2020    1
# 4      1000         5             10           51          0  2020    1
# 5      1000         8             10           96          0  2020    1
# 6      1001         0             10           70          0  2020    1
# 7      1001         1             10           71          0  2020    1
# 8      1001         2             10           71          0  2020    1
# 9      1001         3             10           71          0  2020    1
#
#   disclosure_code  qtrly_estabs  month1_emplvl  ...  oty_month3_emplvl_chg  \
# 0             NaN        129525        1975812  ...                   6243
# 1             NaN          1247          54521  ...                   1524
# 2             NaN          1374          97024  ...                   1238
# 3             NaN          3687         215698  ...                   1286
# 4             NaN        123217        1608569  ...                   2195
# 5             NaN          6308         367243  ...                   4048
# 6             NaN           889          11077  ...                     86
# 7             NaN            10             81  ...                      2
# 8             NaN            19            576  ...                     -6
# 9             NaN            32           1903  ...                     14
#
#    oty_month3_emplvl_pct_chg  oty_total_qtrly_wages_chg  \
# 0                        0.3                  898010082
# 1                        2.8                   -6087967
# 2                        1.3                   78650081
# 3                        0.6                   86640236
# 4                        0.1                  738807732
# 5                        1.1                  159202350
# 6                        0.8                    4973287
# 7                        2.4                      43627
# 8                       -1.0                     368156
# 9                        0.7                     866695
#
#    oty_total_qtrly_wages_pct_chg  oty_taxable_qtrly_wages_chg  \
# 0                            3.7                    198663577
# 1                           -0.5                            0
# 2                            6.3                        46978
# 3                            3.8                      1194244
# 4                            3.8                    197422355
# 5                            3.4                      1241222
# 6                            4.4                      1440687
# 7                            4.2                            0
# 8                            5.8                            0
# 9                            4.7                         3694
#
#    oty_taxable_qtrly_wages_pct_chg oty_qtrly_contributions_chg  \
# 0                              2.0                    -7200684
# 1                              0.0                           0
# 2                             52.8                        1277
# 3                              1.2                      -47880
# 4                              2.0                    -7154081
# 5                              1.3                      -46603
# 6                              3.1                       41283
# 7                              0.0                           0
# 8                              0.0                           0
# 9                              3.0                          22
#
#    oty_qtrly_contributions_pct_chg  oty_avg_wkly_wage_chg  \
# 0                             -6.0                     28
# 1                              0.0                    -45
# 2                             36.6                     48
# 3                             -5.9                     25
# 4                             -6.0                     29
# 5                             -5.8                     22
# 6                              7.5                     27
# 7                              0.0                     52
# 8                              0.0                     54
# 9                              3.0                     30
#
#    oty_avg_wkly_wage_pct_chg
# 0                        3.0
# 1                       -2.8
# 2                        4.8
# 3                        3.0
# 4                        3.1
# 5                        2.2
# 6                        3.4
# 7                        5.5
# 8                        6.4
# 9                        4.1
#
# [10 rows x 42 columns]

# %%
#test 2
q1.columns
# Out:
# Index(['area_fips', 'own_code', 'industry_code', 'agglvl_code', 'size_code',
#        'year', 'qtr', 'disclosure_code', 'qtrly_estabs', 'month1_emplvl',
#        'month2_emplvl', 'month3_emplvl', 'total_qtrly_wages',
#        'taxable_qtrly_wages', 'qtrly_contributions', 'avg_wkly_wage',
#        'lq_disclosure_code', 'lq_qtrly_estabs', 'lq_month1_emplvl',
#        'lq_month2_emplvl', 'lq_month3_emplvl', 'lq_total_qtrly_wages',
#        'lq_taxable_qtrly_wages', 'lq_qtrly_contributions', 'lq_avg_wkly_wage',
#        'oty_disclosure_code', 'oty_qtrly_estabs_chg',
#        'oty_qtrly_estabs_pct_chg', 'oty_month1_emplvl_chg',
#        'oty_month1_emplvl_pct_chg', 'oty_month2_emplvl_chg',
#        'oty_month2_emplvl_pct_chg', 'oty_month3_emplvl_chg',
#        'oty_month3_emplvl_pct_chg', 'oty_total_qtrly_wages_chg',
#        'oty_total_qtrly_wages_pct_chg', 'oty_taxable_qtrly_wages_chg',
#        'oty_taxable_qtrly_wages_pct_chg', 'oty_qtrly_contributions_chg',
#        'oty_qtrly_contributions_pct_chg', 'oty_avg_wkly_wage_chg',
#        'oty_avg_wkly_wage_pct_chg'],
#       dtype='object')

# %%
# make a list of df, iterate through them dropping the chaff
dataframes=[q1,q2,q3,q4,q5,q6,q7,q8,q9,q10,q11,q12,q13,q14]
for df in dataframes:
    df.drop(columns=['own_code', 'industry_code', 'agglvl_code', 'size_code','disclosure_code','qtrly_contributions',
                    'lq_disclosure_code','lq_qtrly_contributions','oty_disclosure_code'], inplace=True)

# %%
# ensure that null columns are dropped
q1.head(10)
# Out:
#   area_fips  year  qtr  qtrly_estabs  month1_emplvl  month2_emplvl  \
# 0      1000  2020    1        129525        1975812        1986981
# 1      1000  2020    1          1247          54521          54643
# 2      1000  2020    1          1374          97024          98574
# 3      1000  2020    1          3687         215698         216071
# 4      1000  2020    1        123217        1608569        1617693
# 5      1000  2020    1          6308         367243         369288
# 6      1001  2020    1           889          11077          11045
# 7      1001  2020    1            10             81             84
# 8      1001  2020    1            19            576            583
# 9      1001  2020    1            32           1903           1925
#
#    month3_emplvl  total_qtrly_wages  taxable_qtrly_wages  avg_wkly_wage  ...  \
# 0        1983902        25058375072          10048338782            972  ...
# 1          55021         1100867539                    0           1547  ...
# 2          99035         1328055880               136007           1040  ...
# 3         216805         2375949787             96898653            845  ...
# 4        1613041        20253501866           9951304122            966  ...
# 5         370861         4804873206             97034660           1001  ...
# 6          11070          119286027             48505408            829  ...
# 7             85            1073296                    0            991  ...
# 8            570            6692792                    0            893  ...
# 9           1940           19222214               127672            769  ...
#
#    oty_month3_emplvl_chg  oty_month3_emplvl_pct_chg  \
# 0                   6243                        0.3
# 1                   1524                        2.8
# 2                   1238                        1.3
# 3                   1286                        0.6
# 4                   2195                        0.1
# 5                   4048                        1.1
# 6                     86                        0.8
# 7                      2                        2.4
# 8                     -6                       -1.0
# 9                     14                        0.7
#
#    oty_total_qtrly_wages_chg  oty_total_qtrly_wages_pct_chg  \
# 0                  898010082                            3.7
# 1                   -6087967                           -0.5
# 2                   78650081                            6.3
# 3                   86640236                            3.8
# 4                  738807732                            3.8
# 5                  159202350                            3.4
# 6                    4973287                            4.4
# 7                      43627                            4.2
# 8                     368156                            5.8
# 9                     866695                            4.7
#
#    oty_taxable_qtrly_wages_chg  oty_taxable_qtrly_wages_pct_chg  \
# 0                    198663577                              2.0
# 1                            0                              0.0
# 2                        46978                             52.8
# 3                      1194244                              1.2
# 4                    197422355                              2.0
# 5                      1241222                              1.3
# 6                      1440687                              3.1
# 7                            0                              0.0
# 8                            0                              0.0
# 9                         3694                              3.0
#
#    oty_qtrly_contributions_chg  oty_qtrly_contributions_pct_chg  \
# 0                     -7200684                             -6.0
# 1                            0                              0.0
# 2                         1277                             36.6
# 3                       -47880                             -5.9
# 4                     -7154081                             -6.0
# 5                       -46603                             -5.8
# 6                        41283                              7.5
# 7                            0                              0.0
# 8                            0                              0.0
# 9                           22                              3.0
#
#    oty_avg_wkly_wage_chg  oty_avg_wkly_wage_pct_chg
# 0                     28                        3.0
# 1                    -45                       -2.8
# 2                     48                        4.8
# 3                     25                        3.0
# 4                     29                        3.1
# 5                     22                        2.2
# 6                     27                        3.4
# 7                     52                        5.5
# 8                     54                        6.4
# 9                     30                        4.1
#
# [10 rows x 33 columns]

# %%
#combine into one dataframe
combined_df = pd.concat(dataframes, axis=0, ignore_index=True)
combined_df
# Out:
#        area_fips  year  qtr  qtrly_estabs  month1_emplvl  month2_emplvl  \
# 0           1000  2020    1        129525        1975812        1986981
# 1           1000  2020    1          1247          54521          54643
# 2           1000  2020    1          1374          97024          98574
# 3           1000  2020    1          3687         215698         216071
# 4           1000  2020    1        123217        1608569        1617693
# ...          ...   ...  ...           ...            ...            ...
# 269513     US000  2023    1        304228       21646463       21871965
# 269514     US000  2023    1      11781153      147357561      148132856
# 269515     USCMS  2023    1       8254334      113890383      114389494
# 269516     USMSA  2023    1       9333341      129007151      129642873
# 269517     USNMS  2023    1       2508533       21215987       21369354
#
#         month3_emplvl  total_qtrly_wages  taxable_qtrly_wages  avg_wkly_wage  \
# 0             1983902        25058375072          10048338782            972
# 1               55021         1100867539                    0           1547
# 2               99035         1328055880               136007           1040
# 3              216805         2375949787             96898653            845
# 4             1613041        20253501866           9951304122            966
# ...               ...                ...                  ...            ...
# 269513       21960551       379963997852          14685972046           1339
# 269514      148644649      2804491349120        1114731557741           1457
# 269515      114763403      2252476833096         855645605357           1515
# 269516      130058453      2514895833232         949087243740           1493
# 269517       21469882       359519640362         165644314001           1295
#
#         ...  oty_month3_emplvl_chg  oty_month3_emplvl_pct_chg  \
# 0       ...                   6243                        0.3
# 1       ...                   1524                        2.8
# 2       ...                   1238                        1.3
# 3       ...                   1286                        0.6
# 4       ...                   2195                        0.1
# ...     ...                    ...                        ...
# 269513  ...                 471863                        2.2
# 269514  ...                3718293                        2.6
# 269515  ...                2485068                        2.2
# 269516  ...                2885870                        2.3
# 269517  ...                 866488                        4.2
#
#         oty_total_qtrly_wages_chg  oty_total_qtrly_wages_pct_chg  \
# 0                       898010082                            3.7
# 1                        -6087967                           -0.5
# 2                        78650081                            6.3
# 3                        86640236                            3.8
# 4                       738807732                            3.8
# ...                           ...                            ...
# 269513                37062073991                           10.8
# 269514               242191662460                            9.5
# 269515               179354027574                            8.7
# 269516               204603575749                            8.9
# 269517                46734722419                           14.9
#
#         oty_taxable_qtrly_wages_chg  oty_taxable_qtrly_wages_pct_chg  \
# 0                         198663577                              2.0
# 1                                 0                              0.0
# 2                             46978                             52.8
# 3                           1194244                              1.2
# 4                         197422355                              2.0
# ...                             ...                              ...
# 269513                   1559258922                             11.9
# 269514                  81303862682                              7.9
# 269515                  57886581100                              7.3
# 269516                  64325630102                              7.3
# 269517                  16978232580                             11.4
#
#         oty_qtrly_contributions_chg  oty_qtrly_contributions_pct_chg  \
# 0                          -7200684                             -6.0
# 1                                 0                              0.0
# 2                              1277                             36.6
# 3                            -47880                             -5.9
# 4                          -7154081                             -6.0
# ...                             ...                              ...
# 269513                      4466760                              5.0
# 269514                    185125089                              1.0
# 269515                     63600101                              0.4
# 269516                     66598961                              0.4
# 269517                    118526128                              4.9
#
#         oty_avg_wkly_wage_chg  oty_avg_wkly_wage_pct_chg
# 0                          28                        3.0
# 1                         -45                       -2.8
# 2                          48                        4.8
# 3                          25                        3.0
# 4                          29                        3.1
# ...                       ...                        ...
# 269513                    106                        8.6
# 269514                     88                        6.4
# 269515                     86                        6.0
# 269516                     87                        6.2
# 269517                    117                        9.9
#
# [269518 rows x 33 columns]

# %%
combined_df.to_csv('2020-2023', index=False)
