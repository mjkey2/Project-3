# %%
import os
import pandas as pd
import csv

# %%
#import data
q1_path = "Id/2014 q1.csv"
q2_path = "Id/2014 q2.csv"
q3_path = "Id/2014 q3.csv"
q4_path = "Id/2014 q4.csv"
q5_path = "Id/2015 q1.csv"
q6_path =  "Id/2015 q2.csv"
q7_path = "Id/2015 q3.csv"
q8_path = "Id/2015 q4.csv"
q9_path = "Id/2016 q1.csv"
q10_path = "Id/2016 q2.csv"
q11_path = "Id/2016 q3.csv"
q12_path = "Id/2016 q4.csv"

# %%
#set them all as df
q1 = pd.read_csv(q1_path)
q2 = pd.read_csv(q2_path)
q3 = pd.read_csv(q3_path)
q4 = pd.read_csv(q4_path)
q5 = pd.read_csv(q5_path)
q6 = pd.read_csv(q6_path)
q7 = pd.read_csv(q7_path)
q8 = pd.read_csv(q8_path)
q9 = pd.read_csv(q9_path)
q10 = pd.read_csv(q10_path)
q11 = pd.read_csv(q11_path)
q12 = pd.read_csv(q12_path)
# Out:
# C:\Users\HeatB\AppData\Local\Temp\ipykernel_3956\317180439.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   q1 = pd.read_csv(q1_path)
# C:\Users\HeatB\AppData\Local\Temp\ipykernel_3956\317180439.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   q2 = pd.read_csv(q2_path)
# C:\Users\HeatB\AppData\Local\Temp\ipykernel_3956\317180439.py:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   q3 = pd.read_csv(q3_path)
# C:\Users\HeatB\AppData\Local\Temp\ipykernel_3956\317180439.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   q4 = pd.read_csv(q4_path)
# C:\Users\HeatB\AppData\Local\Temp\ipykernel_3956\317180439.py:6: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   q5 = pd.read_csv(q5_path)
# ...

# %%
#test 1
q1.head(10)
# Out:
#   area_fips  own_code  industry_code  agglvl_code  size_code  year  qtr  \
# 0      1000         0             10           50          0  2014    1
# 1      1000         1             10           51          0  2014    1
# 2      1000         2             10           51          0  2014    1
# 3      1000         3             10           51          0  2014    1
# 4      1000         5             10           51          0  2014    1
# 5      1000         8             10           96          0  2014    1
# 6      1001         0             10           70          0  2014    1
# 7      1001         1             10           71          0  2014    1
# 8      1001         2             10           71          0  2014    1
# 9      1001         3             10           71          0  2014    1
#
#   disclosure_code  qtrly_estabs  month1_emplvl  ...  oty_month3_emplvl_chg  \
# 0             NaN        116272        1827805  ...                  10957
# ...

# %%
#test 2
q1.columns
# Out:
# Index(['area_fips', 'own_code', 'industry_code', 'agglvl_code', 'size_code',
#        'year', 'qtr', 'disclosure_code', 'qtrly_estabs', 'month1_emplvl',
#        'month2_emplvl', 'month3_emplvl', 'total_qtrly_wages',
#        'taxable_qtrly_wages', 'qtrly_contributions', 'avg_wkly_wage',
#        'lq_disclosure_code', 'lq_qtrly_estabs', 'lq_month1_emplvl',
#        'lq_month2_emplvl', 'lq_month3_emplvl', 'lq_total_qtrly_wages',
#        'lq_taxable_qtrly_wages', 'lq_qtrly_contributions', 'lq_avg_wkly_wage',
#        'oty_disclosure_code', 'oty_qtrly_estabs_chg',
#        'oty_qtrly_estabs_pct_chg', 'oty_month1_emplvl_chg',
#        'oty_month1_emplvl_pct_chg', 'oty_month2_emplvl_chg',
#        'oty_month2_emplvl_pct_chg', 'oty_month3_emplvl_chg',
#        'oty_month3_emplvl_pct_chg', 'oty_total_qtrly_wages_chg',
#        'oty_total_qtrly_wages_pct_chg', 'oty_taxable_qtrly_wages_chg',
#        'oty_taxable_qtrly_wages_pct_chg', 'oty_qtrly_contributions_chg',
# ...

# %%
# make a list of df, iterate through them dropping the chaff
dataframes=[q1,q2,q3,q4,q5,q6,q7,q8,q9,q10,q11,q12]
for df in dataframes:
    df.drop(columns=['own_code', 'industry_code', 'agglvl_code', 'size_code','disclosure_code','qtrly_contributions',
                    'lq_disclosure_code','lq_qtrly_contributions','oty_disclosure_code'], inplace=True)

# %%
# ensure that null columns are dropped
q1.head(10)
# Out:
#   area_fips  year  qtr  qtrly_estabs  month1_emplvl  month2_emplvl  \
# 0      1000  2014    1        116272        1827805        1833319
# 1      1000  2014    1          1181          53598          53534
# 2      1000  2014    1          1383          92760          93798
# 3      1000  2014    1          3691         212309         212130
# 4      1000  2014    1        110017        1469138        1473857
# 5      1000  2014    1          6255         358667         359462
# 6      1001  2014    1           814          10309          10413
# 7      1001  2014    1            11             85             84
# 8      1001  2014    1            18            464            465
# 9      1001  2014    1            32           1914           1908
#
#    month3_emplvl  total_qtrly_wages  taxable_qtrly_wages  avg_wkly_wage  ...  \
# 0        1849342        19712038920           8571763096            826  ...
# ...

# %%
#combine into one dataframe
combined_df = pd.concat(dataframes, axis=0, ignore_index=True)
combined_df
# Out:
#        area_fips  year  qtr  qtrly_estabs  month1_emplvl  month2_emplvl  \
# 0           1000  2014    1        116272        1827805        1833319
# 1           1000  2014    1          1181          53598          53534
# 2           1000  2014    1          1383          92760          93798
# 3           1000  2014    1          3691         212309         212130
# 4           1000  2014    1        110017        1469138        1473857
# ...          ...   ...  ...           ...            ...            ...
# 230951     US000  2016    4        299081       21800591       21931892
# 230952     US000  2016    4       9768482      140643811      141128355
# 230953     USCMS  2016    4       7079154      109949334      110434233
# 230954     USMSA  2016    4       7932358      123934543      124485025
# 230955     USNMS  2016    4       1896483       19508923       19447070
#
#         month3_emplvl  total_qtrly_wages  taxable_qtrly_wages  avg_wkly_wage  \
# ...

# %%
combined_df.to_csv('2014-2016', index=False)
